# %%
import numpy as np
import pandas as pd
import sys
import importlib
from tqdm import tqdm

import functools
import numba as nb
from rdkit import Chem, DataStructs, RDLogger
import pyteomics.mgf
import spectrum_utils.spectrum as sus
from matchms.filtering import normalize_intensities

from matplotlib import pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from matplotlib.colors import LogNorm
from matplotlib.gridspec import GridSpec

sys.path.append("../../src/ms_similarity_metrics")
import frequency
import similarity_weighted as similarity
importlib.reload(frequency)
importlib.reload(similarity)
# Out:
# <module 'similarity_weighted' from '/Users/chloe/Desktop/weighted-mod-cosine-sim/notebooks/network_method/../../src/ms_similarity_metrics/similarity_weighted.py'>

# %% [markdown]
# # Get spectra data

# %%
# Spectra and spectrum pairs to include with the following settings.
charges = 0, 1
min_n_peaks = 6
fragment_mz_tolerance = 0.1
min_mass_diff = 1    # Da
max_mass_diff = 200    # Da

# %%
# Profile spectra contain 0 intensity values.
@nb.njit
def is_centroid(intensity_array):
    return np.all(intensity_array > 0)
            

# Convert smiles to mol
@functools.lru_cache
def _smiles_to_mol(smiles):
    try:
        return Chem.MolFromSmiles(smiles)
    except:
        return None

# Assumes that the spectra are sorted by ascending precusor m/z.
@nb.njit
def generate_pairs(
    spectrum_indexes, masses, min_mass_diff, max_mass_diff
):
    for i in range(len(spectrum_indexes)):
        j = i + 1
        while (
            j < len(spectrum_indexes) and
            masses[j] - masses[i] < min_mass_diff
        ):
            j += 1
        while (
            j < len(spectrum_indexes) and
            masses[j] - masses[i] < max_mass_diff
        ):
            yield spectrum_indexes[i]
            yield spectrum_indexes[j]
            j += 1
    
# Function for calulating tanimoto scores
@functools.lru_cache
def tanimoto(smiles1, smiles2):
    mol1, mol2 = _smiles_to_mol(smiles1), _smiles_to_mol(smiles2)
    if mol1 is None or mol2 is None:
        return np.nan
    fp1, fp2 = Chem.RDKFingerprint(mol1), Chem.RDKFingerprint(mol2)
    return DataStructs.TanimotoSimilarity(fp1, fp2)

# %%
# Read all spectra from the MGF.
# ALL_GNPS_NO_PROPOGATED (retrieved on 2022-05-12) downloaded from
# https://gnps-external.ucsd.edu/gnpslibrary

# Spectrum quality filtering:
#   - Don't include propagated spectra (LIBRARYQUALITY==4).
#   - Don't include multiply charged molecules.
#   - Don't include spectra with invalid precursor m/z (0).
#   - Don't include spectra with too few peaks (minimum 6).
#   - Only include positive ion mode spectra.
#   - Only include spectra with [M+H]+ adducts.
#   - Only include centroid data (does not contain zero intensity values).
#   - Only include spectra with InChI and/or SMILES specified.

spectra = []
# Download from https://zenodo.org/record/6829249/files/ALL_GNPS_NO_PROPOGATED.mgf?download=1
filename = ("../../data/ALL_GNPS_NO_PROPOGATED.mgf")

with pyteomics.mgf.MGF(filename) as f_in:
    for spectrum_dict in tqdm(f_in):
        if (
            int(spectrum_dict["params"]["libraryquality"]) <= 3 and
            int(spectrum_dict["params"]["charge"][0]) in charges and
            float(spectrum_dict["params"]["pepmass"][0]) > 0 and
            len(spectrum_dict["m/z array"]) >= min_n_peaks and
            spectrum_dict["params"]["ionmode"] == "Positive" and
            spectrum_dict["params"]["name"].rstrip().endswith(" M+H") and
            is_centroid(spectrum_dict["intensity array"]) and
            (
                spectrum_dict["params"]["inchi"] != "N/A" or
                spectrum_dict["params"]["smiles"] != "N/A"
            )
        ):
            spec = sus.MsmsSpectrum(
                spectrum_dict["params"]["spectrumid"],
                float(spectrum_dict["params"]["pepmass"][0]),
                # Re-assign charge 0 to 1.
                max(int(spectrum_dict["params"]["charge"][0]), 1),
                spectrum_dict["m/z array"],
                spectrum_dict["intensity array"]/max(spectrum_dict["intensity array"]),
            )
            spec.library = spectrum_dict["params"]["organism"]
            spec.inchi = spectrum_dict["params"]["inchi"]
            spec.smiles = spectrum_dict["params"]["smiles"]
            spec.remove_precursor_peak(0.1, "Da")
            spec.filter_intensity(0.01, max_num_peaks=200)
            spectra.append(spec)
# Out:
# 495600it [01:09, 7094.35it/s]

# %%
# Round mz to 1 decimal
for s in spectra:
    s.mz.round(1, out=s.mz)

# %%
# Read in Wout metadata
metadata = pd.read_csv(
    'https://zenodo.org/record/6829249/files/gnps_libraries_metadata.csv?download=1'
)

# %% [markdown]
# # Get frequency data

# %%
# Get pair subset that Wout used
# Download file from s3://enveda-data-user/chloe.engler/cosine_similarity/Wout_data/pairs_subset.txt
with open('../../data/pairs_subset.txt', 'r') as f:
    pairs_subset = f.read().splitlines()
    pairs_subset = pairs_subset[1:]
    pairs_subset = [np.array(pair.split(' ')).astype(int) for pair in pairs_subset]
pairs_subset = np.array(pairs_subset)

# %%
# Get dataframe containing m/z frequency information
frequency_df = pd.read_csv('s3://enveda-data-user/chloe.engler/cosine_similarity/Wout_data/frequency_df.csv')

# Get number of spectra used to generate the frequency_df
# Get file from s3://enveda-data-user/chloe.engler/cosine_similarity/Wout_data/num_spectra.txt
with open('../../data/num_spectra.txt', 'r') as f:
    num_spectra = int(f.read())

# %%
# Get frequency counts
# Get file from s3://enveda-data-user/chloe.engler/cosine_similarity/Wout_data/frequency_count.txt
with open('../../data/frequency_count.txt', 'r') as f:
    frequency_count = f.read().splitlines()
    frequency_count = frequency_count[1:]
    frequency_count = [float(x) for x in frequency_count]

# %%
# Get sample of pairs
np.random.seed(1)
#small_sample = pairs_subset[np.random.choice(pairs_subset.shape[0], 1_000_000, replace=False)]
small_sample = pairs_subset.copy()

# %% [markdown]
# # Get weights

# %%
# Define weight functions
idf_dict = frequency.idf(frequency_df, num_spectra, frequency_col='frequency')
weight_func = lambda x: x**(1/2) 
intensity_weight_func = lambda x: x**(1/2)
# Get dataframe of weights for m/z frequency
weight_df = frequency.get_weights(frequency_df, weight_func, weight_col='prob')


# # Define weight functions without mz
# idf_dict = frequency.idf(frequency_df, num_spectra, frequency_col='frequency')
# weight_func = lambda x: 1
# intensity_weight_func = lambda x: x**(1/4)
# # Get dataframe of weights for m/z frequency
# weight_df = frequency.get_weights(frequency_df, weight_func, weight_col='prob')

# # Define binary weights
# idf_dict = frequency.idf(frequency_df, num_spectra, frequency_col='frequency')
# weight_func = lambda x: 1
# intensity_weight_func = lambda x: np.ones(len(x))
# # Get dataframe of weights for m/z frequency
# weight_df = frequency.get_weights(frequency_df, weight_func, weight_col='prob')

# #Define Stein weights
# mz_weight_func = lambda x: x**(2)
# intensity_weight_func = lambda x: x**(0.6)
# # Get dataframe of weights for m/z frequency
# weight_df = frequency.get_weights(frequency_df, mz_weight_func, weight_col='prob')
# # Create stein_weight_df
# stein_weight_df = pd.DataFrame(index=weight_df.index.values, columns=['mz', 'weight'])
# stein_weight_df['mz'] = weight_df['mz'].copy()
# stein_weight_df['weight'] = weight_df['mz'].apply(lambda x: mz_weight_func(x))
# weight_df = stein_weight_df.copy()

# %% [markdown]
# # Get similarities

# %%
# Compute similarities between spectrum pairs.
weight_scores = []
mod_scores = []
neutral_loss_scores = []
for i, j in tqdm(small_sample):

    # Get weighted and modified cosine similarity
    weight_cos = similarity.weighted_modified_cosine(spectra[i], spectra[j], fragment_mz_tolerance, 
                                                     weight_df, intensity_weight_func=intensity_weight_func)
    mod_cos = similarity.modified_cosine(spectra[i], spectra[j], fragment_mz_tolerance)

    # save scores
    tan = tanimoto(metadata.at[i, "smiles"], metadata.at[j, "smiles"])
    weight_scores.append((weight_cos[0], weight_cos[1], tan))
    mod_scores.append((mod_cos[0], mod_cos[1], tan))

# save score information
similarities = pd.DataFrame(
    {
        "pair1": small_sample[:, 0],
        "pair2": small_sample[:, 1],
        "id1": metadata.loc[small_sample[:, 0], "id"].values,
        "id2": metadata.loc[small_sample[:, 1], "id"].values,
        "smiles1": metadata.loc[small_sample[:, 0], "smiles"].values,
        "smiles2": metadata.loc[small_sample[:, 1], "smiles"].values,
        "charge1": metadata.loc[small_sample[:, 0], "charge"].values,
        "charge2": metadata.loc[small_sample[:, 1], "charge"].values,
        "mz1": metadata.loc[small_sample[:, 0], "mz"].values,
        "mz2": metadata.loc[small_sample[:, 1], "mz"].values,
    }
)

similarities[
    [
        "weighted_modified_cosine",
        "weighted_modified_cosine_explained",
        "tanimoto",
    ]
] = weight_scores

similarities[
    [
        "modified_cosine",
        "modified_cosine_explained",
        "tanimoto",
    ]
] = mod_scores
# Out:
#   0%|                                 | 373/10000000 [00:00<6:21:00, 437.42it/s][18:17:23] Explicit valence for atom # 19 N, 4, is greater than permitted
#   0%|                                | 1459/10000000 [00:03<5:57:04, 466.69it/s][18:17:25] Explicit valence for atom # 22 N, 4, is greater than permitted
#   0%|                                | 3449/10000000 [00:07<6:17:28, 441.38it/s][18:17:30] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:17:30] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   0%|                                | 4161/10000000 [00:09<6:21:12, 437.03it/s][18:17:32] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:17:32] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   0%|                                | 4651/10000000 [00:10<6:27:56, 429.42it/s][18:17:33] Explicit valence for atom # 22 N, 4, is greater than permitted
#   0%|                                | 5392/10000000 [00:12<6:49:13, 407.06it/s][18:17:34] Explicit valence for atom # 22 N, 4, is greater than permitted
#   0%|                                | 6971/10000000 [00:16<6:17:30, 441.18it/s][18:17:38] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#   0%|                                | 7016/10000000 [00:16<6:33:49, 422.90it/s][18:17:38] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   0%|                                | 7302/10000000 [00:16<6:10:44, 449.23it/s][18:17:39] Explicit valence for atom # 19 N, 4, is greater than permitted
#   0%|                                | 8698/10000000 [00:19<6:26:45, 430.56it/s][18:17:42] Explicit valence for atom # 19 N, 4, is greater than permitted
#   0%|                               | 16318/10000000 [00:37<7:33:24, 366.99it/s][18:17:59] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:17:59] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   0%|                               | 18273/10000000 [00:41<6:11:46, 447.48it/s][18:18:04] Explicit valence for atom # 17 N, 4, is greater than permitted
#   0%|                               | 18417/10000000 [00:41<6:05:16, 455.44it/s][18:18:04] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   0%|                               | 19674/10000000 [00:44<6:02:07, 459.34it/s][18:18:07] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   0%|                               | 23256/10000000 [00:52<7:12:12, 384.72it/s][18:18:15] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:18:15] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   0%|                               | 23523/10000000 [00:53<6:21:45, 435.54it/s][18:18:15] Explicit valence for atom # 22 N, 4, is greater than permitted
#   0%|                               | 24307/10000000 [00:55<6:16:11, 441.96it/s][18:18:17] Explicit valence for atom # 19 N, 4, is greater than permitted
#   0%|                               | 27410/10000000 [01:02<6:22:12, 434.87it/s][18:18:24] Explicit valence for atom # 17 N, 4, is greater than permitted
#   0%|                               | 29694/10000000 [01:07<6:16:30, 441.35it/s][18:18:30] Explicit valence for atom # 35 O, 3, is greater than permitted
#   0%|                               | 30487/10000000 [01:09<6:19:28, 437.87it/s][18:18:31] Explicit valence for atom # 35 O, 3, is greater than permitted
#   0%|                               | 30815/10000000 [01:10<6:02:17, 458.61it/s][18:18:32] Explicit valence for atom # 19 N, 4, is greater than permitted
#   0%|                               | 31347/10000000 [01:11<6:26:24, 429.98it/s][18:18:34] Explicit valence for atom # 22 N, 4, is greater than permitted
#   0%|                               | 31818/10000000 [01:12<5:45:56, 480.24it/s][18:18:35] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:18:35] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   0%|                               | 33450/10000000 [01:16<6:19:11, 438.06it/s][18:18:38] Explicit valence for atom # 7 O, 3, is greater than permitted
#   0%|                               | 34155/10000000 [01:17<6:05:41, 454.19it/s][18:18:40] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   0%|                               | 34641/10000000 [01:18<6:03:22, 457.07it/s][18:18:41] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   0%|                               | 36424/10000000 [01:23<6:50:50, 404.20it/s][18:18:45] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:18:45] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   0%|                               | 38817/10000000 [01:28<6:05:05, 454.74it/s][18:18:50] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   0%|▏                              | 43530/10000000 [01:38<6:57:42, 397.27it/s][18:19:01] Explicit valence for atom # 17 N, 4, is greater than permitted
#   0%|▏                              | 44402/10000000 [01:40<5:56:54, 464.90it/s][18:19:03] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   0%|▏                              | 45836/10000000 [01:44<6:17:16, 439.74it/s][18:19:06] Explicit valence for atom # 35 O, 3, is greater than permitted
#   0%|▏                              | 46029/10000000 [01:44<5:59:10, 461.88it/s][18:19:07] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   0%|▏                              | 47430/10000000 [01:47<6:01:01, 459.47it/s][18:19:10] Explicit valence for atom # 17 N, 4, is greater than permitted
#   0%|▏                              | 48388/10000000 [01:49<6:16:54, 440.05it/s][18:19:12] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   0%|▏                              | 48714/10000000 [01:50<6:09:21, 449.03it/s][18:19:13] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:19:13] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   0%|▏                              | 48764/10000000 [01:50<5:59:27, 461.40it/s][18:19:13] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   0%|▏                              | 49613/10000000 [01:52<5:56:01, 465.81it/s][18:19:14] Explicit valence for atom # 22 N, 4, is greater than permitted
#   1%|▏                              | 53852/10000000 [02:01<5:51:01, 472.24it/s][18:19:24] Explicit valence for atom # 22 N, 4, is greater than permitted
#   1%|▏                              | 56743/10000000 [02:08<5:46:49, 477.81it/s][18:19:30] Explicit valence for atom # 19 N, 4, is greater than permitted
#   1%|▏                              | 57737/10000000 [02:10<6:13:54, 443.17it/s][18:19:33] Explicit valence for atom # 17 N, 4, is greater than permitted
#   1%|▏                              | 61664/10000000 [02:18<6:17:17, 439.02it/s][18:19:41] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   1%|▏                              | 62234/10000000 [02:20<5:55:31, 465.86it/s][18:19:42] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:19:42] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   1%|▏                              | 62569/10000000 [02:20<6:07:59, 450.08it/s][18:19:43] Explicit valence for atom # 19 N, 4, is greater than permitted
#   1%|▏                              | 62907/10000000 [02:21<6:05:00, 453.74it/s][18:19:44] Explicit valence for atom # 22 O, 3, is greater than permitted
#   1%|▏                              | 65061/10000000 [02:26<5:46:07, 478.39it/s][18:19:48] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   1%|▏                              | 66035/10000000 [02:28<6:00:10, 459.68it/s][18:19:51] Explicit valence for atom # 19 N, 4, is greater than permitted
#   1%|▏                              | 68768/10000000 [02:34<5:56:31, 464.25it/s][18:19:56] Explicit valence for atom # 17 N, 4, is greater than permitted
#   1%|▏                              | 69016/10000000 [02:34<5:41:52, 484.15it/s][18:19:57] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   1%|▏                              | 71254/10000000 [02:39<6:34:53, 419.05it/s][18:20:02] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   1%|▏                              | 71950/10000000 [02:41<6:02:41, 456.23it/s][18:20:04] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   1%|▏                              | 77751/10000000 [02:54<5:52:43, 468.83it/s][18:20:16] Explicit valence for atom # 22 N, 4, is greater than permitted
#   1%|▏                              | 80575/10000000 [03:00<6:10:57, 445.67it/s][18:20:23] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:20:23] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   1%|▎                              | 81267/10000000 [03:02<6:13:53, 442.14it/s][18:20:24] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:20:24] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   1%|▎                              | 81921/10000000 [03:03<6:31:35, 422.12it/s][18:20:26] Explicit valence for atom # 22 N, 4, is greater than permitted
#   1%|▎                              | 82863/10000000 [03:05<6:05:45, 451.91it/s][18:20:28] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   1%|▎                              | 85807/10000000 [03:12<5:51:51, 469.61it/s][18:20:34] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   1%|▎                              | 85854/10000000 [03:12<6:01:57, 456.51it/s][18:20:34] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
# [18:20:34] Explicit valence for atom # 19 N, 4, is greater than permitted
#   1%|▎                              | 87157/10000000 [03:15<6:14:35, 441.06it/s][18:20:37] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:20:37] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   1%|▎                              | 92301/10000000 [03:26<5:53:07, 467.63it/s][18:20:49] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   1%|▎                              | 95569/10000000 [03:33<6:12:32, 443.10it/s][18:20:56] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#   1%|▎                              | 97325/10000000 [03:37<5:56:28, 462.98it/s][18:20:59] Explicit valence for atom # 22 N, 4, is greater than permitted
#   1%|▎                             | 102547/10000000 [03:49<6:01:04, 456.84it/s][18:21:11] Explicit valence for atom # 17 N, 4, is greater than permitted
#   1%|▎                             | 107436/10000000 [03:59<6:06:45, 449.55it/s][18:21:22] Explicit valence for atom # 35 O, 3, is greater than permitted
#   1%|▎                             | 108721/10000000 [04:02<6:22:39, 430.82it/s][18:21:25] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   1%|▎                             | 111040/10000000 [04:08<5:53:30, 466.24it/s][18:21:30] Explicit valence for atom # 19 N, 4, is greater than permitted
#   1%|▎                             | 112247/10000000 [04:10<6:07:16, 448.69it/s][18:21:33] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:21:33] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   1%|▎                             | 112294/10000000 [04:10<6:07:04, 448.95it/s][18:21:33] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   1%|▎                             | 116123/10000000 [04:19<5:59:14, 458.56it/s][18:21:41] Explicit valence for atom # 19 N, 4, is greater than permitted
#   1%|▎                             | 116553/10000000 [04:20<5:53:54, 465.44it/s][18:21:42] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:21:42] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   1%|▎                             | 117114/10000000 [04:21<6:05:41, 450.42it/s][18:21:44] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   1%|▎                             | 123806/10000000 [04:36<5:50:20, 469.84it/s][18:21:58] Explicit valence for atom # 22 N, 4, is greater than permitted
#   1%|▎                             | 124976/10000000 [04:38<5:59:54, 457.30it/s][18:22:01] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   1%|▍                             | 125582/10000000 [04:40<5:56:56, 461.08it/s][18:22:02] Explicit valence for atom # 35 O, 3, is greater than permitted
#   1%|▍                             | 125819/10000000 [04:40<6:04:02, 452.06it/s][18:22:03] Explicit valence for atom # 35 O, 3, is greater than permitted
#   1%|▍                             | 136194/10000000 [05:03<6:16:17, 436.89it/s][18:22:26] Explicit valence for atom # 35 O, 3, is greater than permitted
#   1%|▍                             | 142279/10000000 [05:17<6:17:15, 435.49it/s][18:22:39] Explicit valence for atom # 17 N, 4, is greater than permitted
#   1%|▍                             | 142458/10000000 [05:17<6:22:28, 429.56it/s][18:22:40] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   1%|▍                             | 142506/10000000 [05:17<6:10:06, 443.89it/s][18:22:40] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   1%|▍                             | 144756/10000000 [05:22<6:05:11, 449.78it/s][18:22:45] Explicit valence for atom # 22 N, 4, is greater than permitted
#   1%|▍                             | 146740/10000000 [05:27<6:23:11, 428.56it/s][18:22:49] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   1%|▍                             | 148664/10000000 [05:31<5:40:59, 481.51it/s][18:22:53] Explicit valence for atom # 19 N, 4, is greater than permitted
#   2%|▍                             | 154796/10000000 [05:44<5:58:58, 457.11it/s][18:23:07] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:23:07] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   2%|▍                             | 157174/10000000 [05:49<5:52:55, 464.82it/s][18:23:12] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▍                             | 159663/10000000 [05:55<5:49:09, 469.71it/s][18:23:17] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   2%|▍                             | 160759/10000000 [05:57<6:12:30, 440.22it/s][18:23:20] Explicit valence for atom # 6 O, 3, is greater than permitted
#   2%|▍                             | 163732/10000000 [06:04<5:49:31, 469.02it/s][18:23:26] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   2%|▍                             | 163924/10000000 [06:04<5:59:31, 455.98it/s][18:23:27] Explicit valence for atom # 17 N, 4, is greater than permitted
#   2%|▌                             | 167413/10000000 [06:12<5:52:17, 465.18it/s][18:23:34] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:23:34] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   2%|▌                             | 168743/10000000 [06:15<6:10:11, 442.63it/s][18:23:37] Explicit valence for atom # 19 N, 4, is greater than permitted
#   2%|▌                             | 169080/10000000 [06:15<5:49:13, 469.18it/s][18:23:38] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▌                             | 170721/10000000 [06:19<6:02:45, 451.61it/s][18:23:41] Explicit valence for atom # 17 N, 4, is greater than permitted
#   2%|▌                             | 174860/10000000 [06:28<6:02:10, 452.14it/s][18:23:50] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▌                             | 175245/10000000 [06:29<5:59:22, 455.64it/s][18:23:51] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▌                             | 179924/10000000 [06:39<5:40:25, 480.77it/s][18:24:01] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   2%|▌                             | 180452/10000000 [06:40<6:02:33, 451.40it/s][18:24:02] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▌                             | 181138/10000000 [06:41<5:53:07, 463.43it/s][18:24:04] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   2%|▌                             | 181378/10000000 [06:42<6:02:27, 451.48it/s][18:24:04] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   2%|▌                             | 182817/10000000 [06:45<5:43:44, 476.00it/s][18:24:08] Explicit valence for atom # 22 N, 4, is greater than permitted
#   2%|▌                             | 186150/10000000 [06:52<5:38:14, 483.57it/s][18:24:15] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▌                             | 190213/10000000 [07:01<5:48:36, 468.99it/s][18:24:24] Explicit valence for atom # 19 N, 4, is greater than permitted
#   2%|▌                             | 191400/10000000 [07:04<5:38:05, 483.54it/s][18:24:26] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#   2%|▌                             | 194078/10000000 [07:10<6:11:40, 439.72it/s][18:24:32] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:24:32] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   2%|▌                             | 195539/10000000 [07:13<5:52:31, 463.53it/s][18:24:35] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   2%|▌                             | 196217/10000000 [07:14<6:09:43, 441.94it/s][18:24:37] Explicit valence for atom # 17 N, 4, is greater than permitted
#   2%|▌                             | 198310/10000000 [07:19<5:47:33, 470.02it/s][18:24:42] Explicit valence for atom # 6 O, 3, is greater than permitted
#   2%|▌                             | 198745/10000000 [07:20<5:40:42, 479.44it/s][18:24:42] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:24:42] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   2%|▌                             | 201169/10000000 [07:25<6:09:57, 441.44it/s][18:24:48] Explicit valence for atom # 17 N, 4, is greater than permitted
#   2%|▌                             | 201585/10000000 [07:26<6:09:49, 441.59it/s][18:24:49] Explicit valence for atom # 17 N, 4, is greater than permitted
#   2%|▌                             | 203617/10000000 [07:31<6:08:17, 443.33it/s][18:24:53] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:24:53] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   2%|▌                             | 204296/10000000 [07:32<6:20:24, 429.18it/s][18:24:55] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   2%|▌                             | 205687/10000000 [07:36<6:27:23, 421.37it/s][18:24:58] Explicit valence for atom # 6 O, 3, is greater than permitted
#   2%|▋                             | 210374/10000000 [07:46<6:07:12, 444.32it/s][18:25:09] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▋                             | 217470/10000000 [08:02<6:24:27, 424.09it/s][18:25:24] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   2%|▋                             | 219829/10000000 [08:07<6:01:38, 450.73it/s][18:25:30] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▋                             | 229525/10000000 [08:30<6:36:47, 410.39it/s][18:25:52] Explicit valence for atom # 22 N, 4, is greater than permitted
#   2%|▋                             | 232927/10000000 [08:38<6:16:04, 432.85it/s][18:26:01] Explicit valence for atom # 19 N, 4, is greater than permitted
#   2%|▋                             | 233175/10000000 [08:39<7:04:21, 383.59it/s][18:26:01] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   2%|▋                             | 235492/10000000 [08:44<6:37:08, 409.79it/s][18:26:07] Explicit valence for atom # 19 N, 4, is greater than permitted
#   2%|▋                             | 236074/10000000 [08:46<6:35:48, 411.14it/s][18:26:08] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:26:08] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   2%|▋                             | 238360/10000000 [08:51<6:26:56, 420.46it/s][18:26:14] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   2%|▋                             | 239580/10000000 [08:54<5:53:49, 459.75it/s][18:26:17] Explicit valence for atom # 22 N, 4, is greater than permitted
#   2%|▋                             | 241128/10000000 [08:57<6:17:40, 430.66it/s][18:26:20] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:26:20] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   2%|▋                             | 241964/10000000 [08:59<6:26:08, 421.18it/s][18:26:22] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:26:22] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   2%|▋                             | 242699/10000000 [09:01<6:38:00, 408.59it/s][18:26:24] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:26:24] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   2%|▋                             | 243748/10000000 [09:04<6:45:20, 401.15it/s][18:26:27] Explicit valence for atom # 35 O, 3, is greater than permitted
#   2%|▋                             | 245110/10000000 [09:07<6:41:36, 404.83it/s][18:26:30] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:26:30] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   2%|▋                             | 245406/10000000 [09:08<7:07:50, 379.99it/s][18:26:31] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   2%|▋                             | 245667/10000000 [09:09<6:34:52, 411.71it/s][18:26:31] Explicit valence for atom # 22 N, 4, is greater than permitted
#   2%|▋                             | 246031/10000000 [09:09<6:10:48, 438.42it/s][18:26:32] Explicit valence for atom # 6 O, 3, is greater than permitted
#   2%|▋                             | 246297/10000000 [09:10<6:33:34, 413.04it/s][18:26:33] Explicit valence for atom # 19 N, 4, is greater than permitted
#   2%|▋                             | 248358/10000000 [09:15<5:41:49, 475.46it/s][18:26:37] Explicit valence for atom # 22 N, 4, is greater than permitted
#   3%|▊                             | 251527/10000000 [09:22<6:14:56, 433.34it/s][18:26:45] Explicit valence for atom # 22 N, 4, is greater than permitted
#   3%|▊                             | 252550/10000000 [09:25<6:33:38, 412.71it/s][18:26:47] Explicit valence for atom # 19 N, 4, is greater than permitted
#   3%|▊                             | 252730/10000000 [09:25<6:13:50, 434.55it/s][18:26:48] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   3%|▊                             | 253742/10000000 [09:27<6:11:39, 437.06it/s][18:26:50] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#   3%|▊                             | 258431/10000000 [09:38<5:47:19, 467.46it/s][18:27:00] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   3%|▊                             | 260619/10000000 [09:43<5:54:55, 457.35it/s][18:27:05] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#   3%|▊                             | 261385/10000000 [09:44<6:09:24, 439.38it/s][18:27:07] Explicit valence for atom # 4 O, 3, is greater than permitted
#   3%|▊                             | 262563/10000000 [09:47<5:49:26, 464.43it/s][18:27:10] Explicit valence for atom # 17 N, 4, is greater than permitted
#   3%|▊                             | 262710/10000000 [09:47<5:47:27, 467.07it/s][18:27:10] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:27:10] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   3%|▊                             | 263493/10000000 [09:49<5:40:58, 475.92it/s][18:27:12] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:27:12] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   3%|▊                             | 272075/10000000 [10:08<5:47:18, 466.82it/s][18:27:30] Explicit valence for atom # 17 N, 4, is greater than permitted
#   3%|▊                             | 272994/10000000 [10:10<6:32:41, 412.83it/s][18:27:32] Explicit valence for atom # 2 O, 3, is greater than permitted
#   3%|▊                             | 276981/10000000 [10:19<6:26:02, 419.78it/s][18:27:42] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:27:42] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   3%|▊                             | 279954/10000000 [10:26<7:09:47, 376.93it/s][18:27:49] Explicit valence for atom # 19 N, 4, is greater than permitted
#   3%|▊                             | 280989/10000000 [10:29<6:43:39, 401.29it/s][18:27:52] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:27:52] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   3%|▊                             | 284680/10000000 [10:38<6:57:43, 387.62it/s][18:28:01] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:28:01] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   3%|▊                             | 284843/10000000 [10:39<6:51:03, 393.91it/s][18:28:01] Explicit valence for atom # 22 N, 4, is greater than permitted
#   3%|▊                             | 289400/10000000 [10:50<6:31:38, 413.24it/s][18:28:12] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   3%|▊                             | 289705/10000000 [10:51<6:35:30, 409.19it/s][18:28:13] Explicit valence for atom # 19 N, 4, is greater than permitted
#   3%|▉                             | 294377/10000000 [11:02<6:35:54, 408.57it/s][18:28:25] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   3%|▉                             | 295316/10000000 [11:05<6:38:53, 405.48it/s][18:28:27] Explicit valence for atom # 17 N, 4, is greater than permitted
#   3%|▉                             | 295850/10000000 [11:06<6:45:42, 398.65it/s][18:28:29] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   3%|▉                             | 299464/10000000 [11:15<6:42:45, 401.42it/s][18:28:38] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:28:38] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   3%|▉                             | 299850/10000000 [11:16<6:20:43, 424.64it/s][18:28:39] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:28:39] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   3%|▉                             | 305614/10000000 [11:30<5:55:49, 454.09it/s][18:28:53] Explicit valence for atom # 31 O, 3, is greater than permitted
#   3%|▉                             | 307594/10000000 [11:35<6:51:07, 392.93it/s][18:28:57] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:28:57] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   3%|▉                             | 309852/10000000 [11:40<6:26:26, 417.92it/s][18:29:03] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   3%|▉                             | 311273/10000000 [11:44<6:42:22, 401.32it/s][18:29:06] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   3%|▉                             | 311938/10000000 [11:45<6:26:47, 417.45it/s][18:29:08] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
# [18:29:08] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:29:08] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   3%|▉                             | 311982/10000000 [11:45<6:22:42, 421.90it/s][18:29:08] Explicit valence for atom # 19 N, 4, is greater than permitted
#   3%|▉                             | 316649/10000000 [11:56<6:11:09, 434.83it/s][18:29:19] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   3%|▉                             | 316921/10000000 [11:57<6:10:49, 435.20it/s][18:29:20] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   3%|▉                             | 319167/10000000 [12:02<6:06:47, 439.88it/s][18:29:25] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:29:25] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   3%|▉                             | 320791/10000000 [12:06<6:39:07, 404.19it/s][18:29:29] Explicit valence for atom # 35 O, 3, is greater than permitted
#   3%|▉                             | 322345/10000000 [12:10<6:45:14, 398.03it/s][18:29:32] Explicit valence for atom # 17 N, 4, is greater than permitted
#   3%|▉                             | 324327/10000000 [12:15<5:48:34, 462.63it/s][18:29:37] Explicit valence for atom # 19 N, 4, is greater than permitted
#   3%|▉                             | 324893/10000000 [12:16<6:01:04, 446.59it/s][18:29:38] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   3%|▉                             | 327985/10000000 [12:23<6:13:46, 431.27it/s][18:29:45] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:29:45] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   3%|▉                             | 328845/10000000 [12:25<6:12:22, 432.85it/s][18:29:47] Explicit valence for atom # 19 N, 4, is greater than permitted
#   3%|▉                             | 328979/10000000 [12:25<6:17:07, 427.40it/s][18:29:48] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   3%|█                             | 334521/10000000 [12:38<7:22:18, 364.20it/s][18:30:01] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   3%|█                             | 335798/10000000 [12:41<6:14:43, 429.83it/s][18:30:04] Explicit valence for atom # 22 N, 4, is greater than permitted
#   3%|█                             | 338245/10000000 [12:47<6:15:32, 428.79it/s][18:30:10] Explicit valence for atom # 22 N, 4, is greater than permitted
# [18:30:10] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   3%|█                             | 344301/10000000 [13:02<6:10:26, 434.42it/s][18:30:24] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#   3%|█                             | 345165/10000000 [13:04<6:07:57, 437.32it/s][18:30:26] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:30:26] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   3%|█                             | 347997/10000000 [13:10<5:38:18, 475.50it/s][18:30:33] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   3%|█                             | 348276/10000000 [13:11<6:03:04, 443.06it/s][18:30:33] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:30:33] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   3%|█                             | 348322/10000000 [13:11<6:00:21, 446.39it/s][18:30:33] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   4%|█                             | 350602/10000000 [13:16<6:26:59, 415.57it/s][18:30:39] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   4%|█                             | 351896/10000000 [13:20<6:46:02, 396.03it/s][18:30:42] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█                             | 354327/10000000 [13:25<6:14:37, 429.12it/s][18:30:48] Explicit valence for atom # 22 N, 4, is greater than permitted
#   4%|█                             | 355172/10000000 [13:27<6:21:27, 421.40it/s][18:30:50] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:30:50] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   4%|█                             | 357913/10000000 [13:34<6:06:02, 439.03it/s][18:30:56] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█                             | 359591/10000000 [13:38<6:09:24, 434.95it/s][18:31:00] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█                             | 359809/10000000 [13:38<6:28:59, 413.04it/s][18:31:01] Explicit valence for atom # 22 N, 4, is greater than permitted
#   4%|█                             | 362456/10000000 [13:44<5:44:28, 466.30it/s][18:31:07] Explicit valence for atom # 22 N, 4, is greater than permitted
#   4%|█                             | 363056/10000000 [13:46<5:57:01, 449.88it/s][18:31:08] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█                             | 363415/10000000 [13:47<6:28:38, 413.26it/s][18:31:09] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█                             | 363637/10000000 [13:47<6:20:38, 421.94it/s][18:31:10] Explicit valence for atom # 17 N, 4, is greater than permitted
#   4%|█                             | 364927/10000000 [13:50<6:24:10, 418.00it/s][18:31:13] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   4%|█                             | 365429/10000000 [13:52<7:07:21, 375.75it/s][18:31:14] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#   4%|█                             | 372927/10000000 [14:09<6:16:49, 425.79it/s][18:31:32] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:31:32] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   4%|█▏                            | 379417/10000000 [14:25<6:44:57, 395.94it/s][18:31:48] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   4%|█▏                            | 380405/10000000 [14:28<6:31:53, 409.12it/s][18:31:50] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   4%|█▏                            | 382101/10000000 [14:32<6:04:47, 439.42it/s][18:31:54] Explicit valence for atom # 22 N, 4, is greater than permitted
# [18:31:54] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:31:54] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   4%|█▏                            | 382564/10000000 [14:33<6:04:18, 439.99it/s][18:31:56] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▏                            | 389310/10000000 [14:48<6:12:12, 430.34it/s][18:32:11] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   4%|█▏                            | 390154/10000000 [14:50<5:54:44, 451.49it/s][18:32:13] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▏                            | 393606/10000000 [14:58<6:34:27, 405.88it/s][18:32:21] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   4%|█▏                            | 393694/10000000 [14:58<6:22:35, 418.48it/s][18:32:21] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   4%|█▏                            | 397724/10000000 [15:08<6:21:31, 419.47it/s][18:32:30] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▏                            | 397990/10000000 [15:08<6:23:21, 417.45it/s][18:32:31] Explicit valence for atom # 22 O, 3, is greater than permitted
#   4%|█▏                            | 399582/10000000 [15:12<6:06:03, 437.10it/s][18:32:35] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█▏                            | 400452/10000000 [15:14<6:35:37, 404.41it/s][18:32:37] Explicit valence for atom # 35 O, 3, is greater than permitted
#   4%|█▏                            | 400840/10000000 [15:15<6:46:11, 393.87it/s][18:32:38] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   4%|█▏                            | 402552/10000000 [15:19<6:00:12, 444.06it/s][18:32:42] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█▏                            | 405201/10000000 [15:26<6:07:10, 435.52it/s][18:32:48] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:32:48] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   4%|█▏                            | 405247/10000000 [15:26<6:02:38, 440.96it/s][18:32:48] Explicit valence for atom # 17 N, 4, is greater than permitted
#   4%|█▏                            | 406144/10000000 [15:28<6:14:06, 427.42it/s][18:32:50] Explicit valence for atom # 22 N, 4, is greater than permitted
#   4%|█▏                            | 407526/10000000 [15:31<6:04:11, 438.99it/s][18:32:54] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   4%|█▏                            | 408318/10000000 [15:33<6:15:59, 425.17it/s][18:32:56] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:32:56] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   4%|█▏                            | 411282/10000000 [15:40<6:27:05, 412.86it/s][18:33:03] Explicit valence for atom # 35 O, 3, is greater than permitted
#   4%|█▏                            | 412122/10000000 [15:42<6:00:46, 442.93it/s][18:33:05] Explicit valence for atom # 22 N, 4, is greater than permitted
#   4%|█▏                            | 412741/10000000 [15:44<6:21:05, 419.29it/s][18:33:06] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:33:06] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   4%|█▏                            | 416048/10000000 [15:52<6:25:52, 413.96it/s][18:33:14] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#   4%|█▎                            | 417104/10000000 [15:54<6:19:38, 420.70it/s][18:33:17] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [18:33:17] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#   4%|█▎                            | 418698/10000000 [15:58<6:13:56, 427.05it/s][18:33:21] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#   4%|█▎                            | 418840/10000000 [15:58<5:55:52, 448.71it/s][18:33:21] Explicit valence for atom # 22 N, 4, is greater than permitted
#   4%|█▎                            | 419289/10000000 [15:59<6:32:37, 406.70it/s][18:33:22] Explicit valence for atom # 19 N, 4, is greater than permitted
#   4%|█▎                            | 420922/10000000 [16:03<5:53:09, 452.06it/s][18:33:26] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [18:33:26] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#   4%|█▎                            | 422249/10000000 [16:06<6:28:44, 410.64it/s][18:33:29] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▎                            | 422383/10000000 [16:06<6:15:17, 425.33it/s][18:33:29] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#   4%|█▎                            | 423837/10000000 [16:10<5:50:36, 455.21it/s][18:33:32] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▎                            | 427650/10000000 [16:19<6:14:58, 425.46it/s][18:33:41] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▎                            | 428586/10000000 [16:21<6:15:44, 424.55it/s][18:33:43] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▎                            | 429000/10000000 [16:22<5:53:45, 450.91it/s][18:33:44] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▎                            | 431283/10000000 [16:27<6:08:38, 432.62it/s][18:33:50] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#   4%|█▎                            | 433506/10000000 [16:32<6:23:39, 415.59it/s][18:33:55] Explicit valence for atom # 22 N, 4, is greater than permitted
# ...
#  12%|███▍                         | 1205992/10000000 [46:20<5:21:10, 456.34it/s][19:03:43] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [19:03:43] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#  12%|███▍                         | 1206529/10000000 [46:21<5:14:56, 465.36it/s][19:03:44] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  12%|███▌                         | 1207194/10000000 [46:23<5:38:18, 433.18it/s][19:03:45] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  12%|███▌                         | 1210050/10000000 [46:29<5:39:04, 432.06it/s][19:03:52] Explicit valence for atom # 19 N, 4, is greater than permitted
#  12%|███▌                         | 1210412/10000000 [46:30<5:29:04, 445.17it/s][19:03:53] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  12%|███▌                         | 1211042/10000000 [46:31<5:17:31, 461.33it/s][19:03:54] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#  12%|███▌                         | 1211291/10000000 [46:32<5:03:50, 482.09it/s][19:03:54] Explicit valence for atom # 22 N, 4, is greater than permitted
#  12%|███▌                         | 1213905/10000000 [46:38<5:51:37, 416.46it/s][19:04:00] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  12%|███▌                         | 1215018/10000000 [46:40<5:12:14, 468.91it/s][19:04:03] Explicit valence for atom # 22 N, 4, is greater than permitted
#  12%|███▌                         | 1217284/10000000 [46:45<5:24:35, 450.97it/s][19:04:08] Explicit valence for atom # 19 N, 4, is greater than permitted
#  12%|███▌                         | 1218505/10000000 [46:48<5:15:22, 464.08it/s][19:04:10] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  12%|███▌                         | 1223048/10000000 [46:58<5:19:53, 457.29it/s][19:04:20] Explicit valence for atom # 2 O, 3, is greater than permitted
#  12%|███▌                         | 1224153/10000000 [47:00<5:48:39, 419.50it/s][19:04:23] Explicit valence for atom # 19 N, 4, is greater than permitted
#  12%|███▌                         | 1225947/10000000 [47:04<5:16:36, 461.88it/s][19:04:27] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#  12%|███▌                         | 1226045/10000000 [47:05<5:10:39, 470.71it/s][19:04:27] Explicit valence for atom # 19 N, 4, is greater than permitted
#  12%|███▌                         | 1227400/10000000 [47:08<5:23:37, 451.78it/s][19:04:30] Explicit valence for atom # 35 O, 3, is greater than permitted
#  12%|███▌                         | 1228353/10000000 [47:10<5:28:33, 444.95it/s][19:04:32] Explicit valence for atom # 22 N, 4, is greater than permitted
#  12%|███▌                         | 1229673/10000000 [47:12<5:09:54, 471.67it/s][19:04:35] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  12%|███▌                         | 1232881/10000000 [47:19<5:26:36, 447.39it/s][19:04:42] Explicit valence for atom # 17 N, 4, is greater than permitted
#  12%|███▌                         | 1234907/10000000 [47:24<5:30:19, 442.24it/s][19:04:46] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  12%|███▌                         | 1235507/10000000 [47:25<5:18:20, 458.86it/s][19:04:48] Explicit valence for atom # 19 N, 4, is greater than permitted
#  12%|███▌                         | 1236775/10000000 [47:28<5:11:05, 469.48it/s][19:04:51] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  12%|███▌                         | 1242180/10000000 [47:40<5:02:25, 482.65it/s][19:05:02] Explicit valence for atom # 17 N, 4, is greater than permitted
#  12%|███▌                         | 1245031/10000000 [47:46<5:17:21, 459.78it/s][19:05:09] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  13%|███▋                         | 1250360/10000000 [47:58<5:26:44, 446.31it/s][19:05:20] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  13%|███▋                         | 1250870/10000000 [47:59<5:20:14, 455.33it/s][19:05:21] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▋                         | 1255589/10000000 [48:10<5:22:17, 452.20it/s][19:05:33] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▋                         | 1260414/10000000 [48:21<5:11:15, 467.97it/s][19:05:43] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▋                         | 1260756/10000000 [48:21<5:17:07, 459.29it/s][19:05:44] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▋                         | 1261377/10000000 [48:23<5:22:15, 451.96it/s][19:05:45] Explicit valence for atom # 35 O, 3, is greater than permitted
#  13%|███▋                         | 1265119/10000000 [48:31<5:47:10, 419.34it/s][19:05:54] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#  13%|███▋                         | 1267674/10000000 [48:38<6:01:01, 403.12it/s][19:06:00] non-ring atom 88 marked aromatic
#  13%|███▋                         | 1267878/10000000 [48:38<6:14:26, 388.68it/s][19:06:01] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▋                         | 1269157/10000000 [48:41<5:45:21, 421.34it/s][19:06:04] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#  13%|███▋                         | 1270027/10000000 [48:43<5:16:10, 460.18it/s][19:06:06] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  13%|███▋                         | 1270804/10000000 [48:45<5:22:06, 451.68it/s][19:06:07] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  13%|███▋                         | 1279213/10000000 [49:04<5:36:07, 432.42it/s][19:06:26] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [19:06:26] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#  13%|███▋                         | 1281382/10000000 [49:09<5:16:27, 459.17it/s][19:06:31] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▋                         | 1282900/10000000 [49:12<5:09:14, 469.82it/s][19:06:34] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▋                         | 1283041/10000000 [49:12<5:30:21, 439.78it/s][19:06:35] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▋                         | 1285581/10000000 [49:18<5:00:21, 483.57it/s][19:06:40] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▋                         | 1290614/10000000 [49:29<5:05:46, 474.72it/s][19:06:51] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [19:06:51] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#  13%|███▊                         | 1294521/10000000 [49:37<5:20:00, 453.41it/s][19:07:00] Explicit valence for atom # 35 O, 3, is greater than permitted
#  13%|███▊                         | 1299528/10000000 [49:48<5:12:38, 463.82it/s][19:07:11] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#  13%|███▊                         | 1301089/10000000 [49:52<5:31:54, 436.82it/s][19:07:15] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  13%|███▊                         | 1301599/10000000 [49:53<5:24:00, 447.44it/s][19:07:16] Explicit valence for atom # 22 O, 3, is greater than permitted
#  13%|███▊                         | 1303264/10000000 [49:57<5:22:43, 449.13it/s][19:07:19] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  13%|███▊                         | 1304721/10000000 [50:00<5:11:06, 465.82it/s][19:07:23] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [19:07:23] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#  13%|███▊                         | 1304997/10000000 [50:01<5:19:37, 453.39it/s][19:07:23] Explicit valence for atom # 2 O, 3, is greater than permitted
#  13%|███▊                         | 1306265/10000000 [50:03<5:19:24, 453.63it/s][19:07:26] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  13%|███▊                         | 1307867/10000000 [50:07<5:52:07, 411.40it/s][19:07:30] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#  13%|███▊                         | 1308555/10000000 [50:09<5:35:51, 431.31it/s][19:07:31] Explicit valence for atom # 17 N, 4, is greater than permitted
#  13%|███▊                         | 1309385/10000000 [50:10<5:31:37, 436.76it/s][19:07:33] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/C(C1)O)/C)(C)C'
#  13%|███▊                         | 1310184/10000000 [50:12<6:11:23, 389.97it/s][19:07:35] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▊                         | 1310225/10000000 [50:12<6:08:06, 393.45it/s][19:07:35] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1311538/10000000 [50:16<5:12:27, 463.46it/s][19:07:38] Explicit valence for atom # 17 N, 4, is greater than permitted
#  13%|███▊                         | 1312323/10000000 [50:17<5:48:12, 415.83it/s][19:07:40] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1312909/10000000 [50:19<6:14:37, 386.48it/s][19:07:41] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1313309/10000000 [50:20<6:22:08, 378.86it/s][19:07:42] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1314222/10000000 [50:22<6:09:51, 391.41it/s][19:07:45] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  13%|███▊                         | 1315028/10000000 [50:24<5:24:55, 445.49it/s][19:07:47] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
# [19:07:47] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1316124/10000000 [50:26<5:23:17, 447.69it/s][19:07:49] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [19:07:49] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#  13%|███▊                         | 1316816/10000000 [50:28<5:18:38, 454.18it/s][19:07:51] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [19:07:51] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#  13%|███▊                         | 1317932/10000000 [50:30<5:14:49, 459.63it/s][19:07:53] Explicit valence for atom # 17 N, 4, is greater than permitted
#  13%|███▊                         | 1319442/10000000 [50:34<5:08:46, 468.56it/s][19:07:56] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1319536/10000000 [50:34<5:09:18, 467.74it/s][19:07:56] Explicit valence for atom # 35 O, 3, is greater than permitted
#  13%|███▊                         | 1319585/10000000 [50:34<5:05:03, 474.25it/s][19:07:57] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▊                         | 1320030/10000000 [50:35<5:14:44, 459.64it/s][19:07:57] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1322526/10000000 [50:41<5:34:46, 432.01it/s][19:08:03] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  13%|███▊                         | 1322659/10000000 [50:41<5:39:22, 426.15it/s][19:08:04] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▊                         | 1322749/10000000 [50:41<5:33:01, 434.26it/s][19:08:04] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  13%|███▊                         | 1323909/10000000 [50:44<5:18:29, 454.03it/s][19:08:06] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  13%|███▊                         | 1325178/10000000 [50:47<5:35:59, 430.31it/s][19:08:09] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#  13%|███▊                         | 1325227/10000000 [50:47<5:23:16, 447.22it/s][19:08:09] Explicit valence for atom # 19 N, 4, is greater than permitted
#  13%|███▊                         | 1328119/10000000 [50:53<5:39:06, 426.22it/s][19:08:16] Explicit valence for atom # 22 N, 4, is greater than permitted
#  13%|███▊                         | 1332022/10000000 [51:02<5:12:51, 461.76it/s][19:08:25] SMILES Parse Error: extra open parentheses for input: 'COC(=O)C1=CCCC2C3(C)CC(OC(=O)C3CC(OC3OC(CO)C(O)C(O)C3O'
#  13%|███▊                         | 1335032/10000000 [51:09<5:15:55, 457.13it/s][19:08:32] SMILES Parse Error: syntax error while parsing: InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)
# [19:08:32] SMILES Parse Error: Failed parsing SMILES 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)' for input: 'InChI=1S/C16H21NO2/c1-2-3-4-5-6-11-14-16(19)15(18)12-9-7-8-10-13(12)17-14/h7-10,19H,2-6,11H2,1H3,(H,17,18)'
#  13%|███▉                         | 1338544/10000000 [51:17<5:44:40, 418.83it/s][19:08:40] SMILES Parse Error: unclosed ring for input: 'C\CC(/C=C/C(=O)/C(=C/CC1)/C)(C)C'
#  13%|███▉                         | 1342418/10000000 [51:26<5:25:35, 443.17it/s][19:08:49] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  13%|███▉                         | 1346007/10000000 [51:35<5:58:14, 402.62it/s][19:08:57] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  14%|███▉                         | 1350699/10000000 [51:47<5:50:58, 410.73it/s][19:09:10] Explicit valence for atom # 22 N, 4, is greater than permitted
#  14%|███▉                         | 1354601/10000000 [51:56<5:01:18, 478.21it/s][19:09:18] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  14%|███▉                         | 1355331/10000000 [51:57<5:47:41, 414.38it/s][19:09:20] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  14%|███▉                         | 1356104/10000000 [51:59<5:09:22, 465.66it/s][19:09:22] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16
#  14%|███▉                         | 1357364/10000000 [52:02<5:22:53, 446.12it/s][19:09:25] SMILES Parse Error: unclosed ring for input: 'C\CC[C@@]2([C@@H](O2)CC(/C=C/C1=O)(C)C)C'
#  14%|███▉                         | 1359493/10000000 [52:07<5:51:17, 409.93it/s][19:09:29] Explicit valence for atom # 19 N, 4, is greater than permitted
#  14%|███▉                         | 1359669/10000000 [52:07<5:49:47, 411.70it/s][19:09:30] SMILES Parse Error: syntax error while parsing: N/ACCC1(C(=O)NCNC1=O)c2ccccc2
# [19:09:30] SMILES Parse Error: Failed parsing SMILES 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2' for input: 'N/ACCC1(C(=O)NCNC1=O)c2ccccc2'
#  14%|███▉                         | 1361574/10000000 [52:11<5:09:27, 465.24it/s][19:09:34] Explicit valence for atom # 22 N, 4, is greater than permitted
#  14%|███▉                         | 1367136/10000000 [52:23<5:19:05, 450.92it/s][19:09:46] Can't kekulize mol.  Unkekulized atoms: 10 11 12 14 16

# %%
# Normalize scores
if similarities['weighted_modified_cosine'].max() > 1:
    similarities['weighted_modified_cosine'] = similarities['weighted_modified_cosine']/similarities['weighted_modified_cosine'].max()
similarities['weighted_difference'] = abs(similarities['weighted_modified_cosine'] - similarities['modified_cosine'])

# %%
similarities["tanimoto_interval"] = pd.cut(
    similarities["tanimoto"],
    5,
    labels=["0.0–0.2", "0.2–0.4", "0.4–0.6", "0.6–0.8", "0.8–1.0"],
)
similarities_tanimoto = pd.melt(
    similarities,
    id_vars="tanimoto_interval",
    value_vars=["weighted_modified_cosine", "modified_cosine"],
)

# %%
# Look at scores for tanimoto intervals
stats = similarities_tanimoto[similarities_tanimoto.variable != 'neutral_loss']
stats.groupby(['tanimoto_interval', 'variable']).agg(['mean', 'std'])

# %%
# Look at mean difference between cosine scores and tanimoto scores
similarities['weighted_tanimoto_diff'] = abs(similarities['weighted_modified_cosine'] - similarities['tanimoto'])
similarities['modified_tanimoto_diff'] = abs(similarities['modified_cosine'] - similarities['tanimoto'])
print('mean difference between weighted cosine and tanimoto scores: ', similarities['weighted_tanimoto_diff'].mean())
print('mean difference between modified cosine and tanimoto scores: ', similarities['modified_tanimoto_diff'].mean())
similarities[['tanimoto_interval', 'weighted_tanimoto_diff', 'modified_tanimoto_diff']].groupby(['tanimoto_interval']).agg(['mean'])

# %%
# Look at weighted vs. unweighted scores colored by tanimoto scores
similarities.plot.hexbin('weighted_modified_cosine', 'modified_cosine', C='tanimoto', gridsize=30, cmap='inferno')
plt.plot([0,1], [0,1], c='red')
plt.show()

# %% [markdown]
# # Show violin plots

# %%
mosaic = """
11111.
222223
222223
222223
222223
222223
"""

bins = 100
tick_locators = mticker.FixedLocator(np.arange(0, bins + 1, bins / 4))
tick_labels = np.asarray([f"{a:.2f}" for a in np.arange(0, 1.01, 0.25)])

with sns.plotting_context("paper", font_scale=1.6):
    fig = plt.figure(constrained_layout=True, figsize=(7.2 * 2, 7.2 / 1.618 * 3))
    gs = GridSpec(3, 3, figure=fig)
    
    # Top panel: Compare different similarities.
    axes_left = fig.add_subfigure(gs[0, 0]).subplot_mosaic(mosaic)
    axes_middle = fig.add_subfigure(gs[0, 1]).subplot_mosaic(mosaic)
    axes_right = fig.add_subfigure(gs[0, 2]).subplot_mosaic(mosaic)
    cbar_ax = fig.add_axes([-0.04, 0.75, 0.02, 0.15])
    
    labels = np.asarray([
        ["weighted_modified_cosine", "modified_cosine"],
    ])

    for i, (axes, (xlabel, ylabel)) in enumerate(
        zip([axes_left, axes_middle, axes_right], labels)
    ):
        # Plot heatmaps.
        hist, _, _ = np.histogram2d(
            similarities[xlabel],
            similarities[ylabel],
            bins=bins,
            range=[[0, 1], [0, 1]],
        )
        hist /= len(similarities)
        heatmap = sns.heatmap(
            np.rot90(hist),
            vmin=0.0,
            vmax=0.001,
            cmap="viridis",
            cbar=i == 2,
            cbar_kws={"format": mticker.StrMethodFormatter("{x:.3%}")},
            cbar_ax=cbar_ax if i == 2 else None,
            square=True,
            xticklabels=False,
            yticklabels=False,
            ax=axes["2"],
            norm=LogNorm(vmin=0.00001,vmax=0.001),
        )
        axes["2"].yaxis.set_major_locator(tick_locators)
        axes["2"].set_yticklabels(tick_labels[::-1])
        axes["2"].xaxis.set_major_locator(tick_locators)
        axes["2"].set_xticklabels(tick_labels)
        for _, spine in heatmap.spines.items():
            spine.set_visible(True)
        axes["2"].set_xlabel(xlabel.replace("_", " ").capitalize())
        axes["2"].set_ylabel(ylabel.replace("_", " ").capitalize())

        axes["2"].plot(
            [0, bins], [bins, 0], color="black", linestyle="dashed"
        )

        sns.despine(ax=axes["2"])

        # Plot density plots.
        sns.kdeplot(
            data=similarities,
            x=xlabel,
            clip=(0, 1),
            legend=True,
            color="black",
            fill=True,
            ax=axes["1"],
        )
        axes["1"].set_xlim(0, 1)
        axes["1"].xaxis.set_ticklabels([])
        axes["1"].yaxis.set_major_locator(tick_locators)
        axes["1"].set_yticks([])
        sns.despine(ax=axes["1"], left=True)
        sns.kdeplot(
            data=similarities,
            y=ylabel,
            clip=(0, 1),
            legend=True,
            color="black",
            fill=True,
            ax=axes["3"],
        )
        axes["3"].set_ylim(0, 1)
        axes["3"].yaxis.set_ticklabels([])
        axes["3"].xaxis.set_major_locator(tick_locators)
        axes["3"].set_xticks([])
        sns.despine(ax=axes["3"], bottom=True)
        for ax in [axes[c] for c in "13"]:
            ax.set_xlabel("")
            ax.set_ylabel("")
            
    cbar_ax.set_ylabel("Proportion of pairs")
    cbar_ax.yaxis.set_label_position("left")
    # cbar_ax.spines["outline"].set(visible=True, lw=.8, edgecolor="black")
    
    # Middle panel: Compare similarities vs explained intensity.
    axes_left = fig.add_subfigure(gs[1, 0]).subplot_mosaic(mosaic)
    axes_middle = fig.add_subfigure(gs[1, 1]).subplot_mosaic(mosaic)
    axes_right = fig.add_subfigure(gs[1, 2]).subplot_mosaic(mosaic)
    cbar_ax = fig.add_axes([-0.04, 0.45, 0.02, 0.15])
    
    labels = np.asarray([
        ["weighted_modified_cosine_explained", "weighted_modified_cosine"],
        ["modified_cosine_explained", "modified_cosine"],
    ])

    for i, (axes, (xlabel, ylabel)) in enumerate(
        zip([axes_left, axes_middle, axes_right], labels)
    ):
        # Plot heatmaps.
        hist, _, _ = np.histogram2d(
            similarities[xlabel],
            similarities[ylabel],
            bins=bins,
            range=[[0, 1], [0, 1]],
        )
        hist /= len(similarities)
        heatmap = sns.heatmap(
            np.rot90(hist),
            vmin=0.0,
            vmax=0.001,
            cmap="viridis",
            cbar=i == 2,
            cbar_kws={"format": mticker.StrMethodFormatter("{x:.3%}")},
            cbar_ax=cbar_ax if i == 2 else None,
            square=True,
            xticklabels=False,
            yticklabels=False,
            ax=axes["2"],
            norm=LogNorm(vmin=0.00001,vmax=0.001),
        )
        axes["2"].yaxis.set_major_locator(tick_locators)
        axes["2"].set_yticklabels(tick_labels[::-1])
        axes["2"].xaxis.set_major_locator(tick_locators)
        axes["2"].set_xticklabels(tick_labels)
        axes["2"].xaxis.set_major_formatter(mticker.PercentFormatter())
        for _, spine in heatmap.spines.items():
            spine.set_visible(True)
        axes["2"].set_xlabel("Explained intensity")
        axes["2"].set_ylabel(ylabel.replace("_", " ").capitalize())

        sns.despine(ax=axes["2"])

        # Plot density plots.
        sns.kdeplot(
            data=similarities,
            x=xlabel,
            clip=(0, 1),
            legend=True,
            color="black",
            fill=True,
            ax=axes["1"],
        )
        axes["1"].set_xlim(0, 1)
        axes["1"].xaxis.set_ticklabels([])
        axes["1"].yaxis.set_major_locator(tick_locators)
        axes["1"].set_yticks([])
        sns.despine(ax=axes["1"], left=True)
        sns.kdeplot(
            data=similarities,
            y=ylabel,
            clip=(0, 1),
            legend=True,
            color="black",
            fill=True,
            ax=axes["3"],
        )
        axes["3"].set_ylim(0, 1)
        axes["3"].yaxis.set_ticklabels([])
        axes["3"].xaxis.set_major_locator(tick_locators)
        axes["3"].set_xticks([])
        sns.despine(ax=axes["3"], bottom=True)
        for ax in [axes[c] for c in "13"]:
            ax.set_xlabel("")
            ax.set_ylabel("")
            
    cbar_ax.set_ylabel("Proportion of pairs")
    cbar_ax.yaxis.set_label_position("left")
    # cbar_ax.spines["outline"].set(visible=True, lw=.8, edgecolor="black")
    
    # Bottom panel: Evaluate similarities in terms of the Tanimoto index.
    ax = fig.add_subplot(gs[2, :])
    
    sns.violinplot(
        data=similarities_tanimoto,
        x="tanimoto_interval",
        y="value",
        hue="variable",
        hue_order=["weighted_modified_cosine", "modified_cosine"],
        cut=0,
        scale="width",
        scale_hue=False,
        ax=ax,
    )
    ax.set_xlabel("Tanimoto index")
    ax.set_ylabel("Spectrum similarity")
    for label in ax.legend().get_texts():
        label.set_text(label.get_text().replace("_", " ").capitalize())
    sns.move_legend(
        ax,
        "lower center",
        bbox_to_anchor=(.5, 1),
        ncol=3,
        title=None,
        frameon=False,
    )

    sns.despine(ax=ax)
    
    # Subplot labels.
    for y, label in zip([1, 2/3, 0.35], "abc"):
        fig.text(
            -0.05, y, label, fontdict=dict(fontsize="xx-large", weight="bold")
        )

    # Save figure.
    plt.savefig("gnps_libraries.png", dpi=300, bbox_inches="tight")
    plt.show()
    plt.close()

# %%
similarities.to_csv('../../data/network_method/similarities_10m_stein_0.6_2.csv')

# %%
similarities.to_csv('s3://enveda-data-user/chloe.engler/cosine_similarity/network_method/similarities_10m_stein_0.6_2.csv')
